# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)

# %%
import pandas as pd
import numpy as np
import nltk
import re
import string
from collections import Counter
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.drop_duplicates(inplace=True)
df.reset_index()
# Out:
#        index                                             review sentiment
# 0          0  One of the other reviewers has mentioned that ...  positive
# 1          1  A wonderful little production. <br /><br />The...  positive
# 2          2  I thought this was a wonderful way to spend ti...  positive
# 3          3  Basically there's a family where a little boy ...  negative
# 4          4  Petter Mattei's "Love in the Time of Money" is...  positive
# ...      ...                                                ...       ...
# 49577  49995  I thought this movie did a down right good job...  positive
# 49578  49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49579  49997  I am a Catholic taught in parochial elementary...  negative
# 49580  49998  I'm going to have to disagree with the previou...  negative
# 49581  49999  No one expects the Star Trek movies to be high...  negative
#
# [49582 rows x 3 columns]

# %%
def clean_text(text):
    text = re.sub('<[^<]+?>', '', text)
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\d+', '', text)
    return text

# %%
df.loc[:, 'review'] = df['review'].apply(clean_text)

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production the filming tech...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically theres a family where a little boy j...  negative
# 4      petter matteis love in the time of money is a ...  positive
# ...                                                  ...       ...
# 49577  i thought this movie did a down right good job...  positive
# 49578  bad plot bad dialogue bad acting idiotic direc...  negative
# 49579  i am a catholic taught in parochial elementary...  negative
# 49580  im going to have to disagree with the previous...  negative
# 49581  no one expects the star trek movies to be high...  negative
#
# [49582 rows x 2 columns]

# %%
review = df.review.apply(lambda x : word_tokenize(x))
target = df.sentiment

# %%
vocab = Counter(word for element in review for word in element)

# %%
vocab = {word : idx + 1 for idx, (word, _) in enumerate(vocab.most_common())}

# %%
vocab
# Out:
# {'the': 1,
#  'and': 2,
#  'a': 3,
#  'of': 4,
#  'to': 5,
#  'is': 6,
#  'in': 7,
#  'it': 8,
#  'i': 9,
#  'this': 10,
#  'that': 11,
#  'was': 12,
#  'as': 13,
#  'with': 14,
#  'for': 15,
#  'movie': 16,
#  'but': 17,
#  'film': 18,
#  'on': 19,
#  'not': 20,
#  'you': 21,
#  'are': 22,
#  'his': 23,
#  'have': 24,
#  'be': 25,
#  'he': 26,
#  'one': 27,
#  'its': 28,
#  'at': 29,
#  'all': 30,
#  'by': 31,
#  'an': 32,
#  'they': 33,
#  'who': 34,
#  'from': 35,
#  'like': 36,
#  'so': 37,
#  'or': 38,
#  'just': 39,
#  'her': 40,
#  'about': 41,
#  'has': 42,
#  'out': 43,
#  'if': 44,
#  'some': 45,
#  'what': 46,
#  'there': 47,
#  'good': 48,
#  'more': 49,
#  'very': 50,
#  'when': 51,
#  'even': 52,
#  'up': 53,
#  'no': 54,
#  'my': 55,
#  'would': 56,
#  'can': 57,
#  'she': 58,
#  'time': 59,
#  'which': 60,
#  'only': 61,
#  'really': 62,
#  'their': 63,
#  'see': 64,
#  'were': 65,
#  'story': 66,
#  'had': 67,
#  'me': 68,
#  'than': 69,
#  'much': 70,
#  'we': 71,
#  'well': 72,
#  'been': 73,
#  'get': 74,
#  'will': 75,
#  'other': 76,
#  'into': 77,
#  'great': 78,
#  'do': 79,
#  'bad': 80,
#  'because': 81,
#  'also': 82,
#  'people': 83,
#  'how': 84,
#  'most': 85,
#  'him': 86,
#  'first': 87,
#  'dont': 88,
#  'movies': 89,
#  'made': 90,
#  'them': 91,
#  'then': 92,
#  'films': 93,
#  'make': 94,
#  'could': 95,
#  'way': 96,
#  'any': 97,
#  'too': 98,
#  'characters': 99,
#  'after': 100,
#  'think': 101,
#  'watch': 102,
#  'many': 103,
#  'seen': 104,
#  'being': 105,
#  'character': 106,
#  'two': 107,
#  'never': 108,
#  'love': 109,
#  'acting': 110,
#  'where': 111,
#  'did': 112,
#  'plot': 113,
#  'best': 114,
#  'little': 115,
#  'know': 116,
#  'show': 117,
#  'life': 118,
#  'ever': 119,
#  'does': 120,
#  'your': 121,
#  'better': 122,
#  'off': 123,
#  'over': 124,
#  'say': 125,
#  'still': 126,
#  'these': 127,
#  'scene': 128,
#  'end': 129,
#  'man': 130,
#  'scenes': 131,
#  'why': 132,
#  'here': 133,
#  'such': 134,
#  'while': 135,
#  'something': 136,
#  'go': 137,
#  'should': 138,
#  'through': 139,
#  'those': 140,
#  'back': 141,
#  'real': 142,
#  'im': 143,
#  'watching': 144,
#  'thing': 145,
#  'doesnt': 146,
#  'didnt': 147,
#  'actors': 148,
#  'years': 149,
#  'now': 150,
#  'actually': 151,
#  'though': 152,
#  'makes': 153,
#  'funny': 154,
#  'before': 155,
#  'another': 156,
#  'find': 157,
#  'nothing': 158,
#  'look': 159,
#  's': 160,
#  'going': 161,
#  'work': 162,
#  'same': 163,
#  'lot': 164,
#  'new': 165,
#  'few': 166,
#  'every': 167,
#  'old': 168,
#  'us': 169,
#  'part': 170,
#  'cant': 171,
#  'again': 172,
#  'director': 173,
#  'want': 174,
#  'quite': 175,
#  'thats': 176,
#  'got': 177,
#  'things': 178,
#  'pretty': 179,
#  'cast': 180,
#  'seems': 181,
#  'around': 182,
#  'young': 183,
#  'down': 184,
#  'take': 185,
#  'fact': 186,
#  'world': 187,
#  'enough': 188,
#  'big': 189,
#  'both': 190,
#  'horror': 191,
#  'thought': 192,
#  'give': 193,
#  'may': 194,
#  'between': 195,
#  'own': 196,
#  'ive': 197,
#  'however': 198,
#  'without': 199,
#  'saw': 200,
#  'long': 201,
#  'isnt': 202,
#  'gets': 203,
#  'always': 204,
#  'right': 205,
#  'music': 206,
#  'original': 207,
#  'almost': 208,
#  'must': 209,
#  'come': 210,
#  'comedy': 211,
#  'times': 212,
#  'whole': 213,
#  'role': 214,
#  'series': 215,
#  'least': 216,
#  'interesting': 217,
#  'guy': 218,
#  'action': 219,
#  'point': 220,
#  'bit': 221,
#  'done': 222,
#  'theres': 223,
#  'am': 224,
#  'might': 225,
#  'far': 226,
#  'minutes': 227,
#  'hes': 228,
#  'script': 229,
#  'feel': 230,
#  'anything': 231,
#  'last': 232,
#  'since': 233,
#  'probably': 234,
#  'family': 235,
#  'kind': 236,
#  'performance': 237,
#  'tv': 238,
#  'away': 239,
#  'rather': 240,
#  'yet': 241,
#  'worst': 242,
#  'each': 243,
#  'fun': 244,
#  'found': 245,
#  'anyone': 246,
#  'sure': 247,
#  'played': 248,
#  'girl': 249,
#  'making': 250,
#  'our': 251,
#  'believe': 252,
#  'woman': 253,
#  'trying': 254,
#  'shows': 255,
#  'especially': 256,
#  'course': 257,
#  'having': 258,
#  'comes': 259,
#  'hard': 260,
#  'goes': 261,
#  'day': 262,
#  'put': 263,
#  'everything': 264,
#  'although': 265,
#  'different': 266,
#  'worth': 267,
#  'looking': 268,
#  'dvd': 269,
#  'main': 270,
#  'place': 271,
#  'ending': 272,
#  'looks': 273,
#  'wasnt': 274,
#  'maybe': 275,
#  'watched': 276,
#  'book': 277,
#  'sense': 278,
#  'reason': 279,
#  'screen': 280,
#  'once': 281,
#  'three': 282,
#  'set': 283,
#  'effects': 284,
#  'plays': 285,
#  'true': 286,
#  'someone': 287,
#  'play': 288,
#  'job': 289,
#  'money': 290,
#  'actor': 291,
#  'during': 292,
#  'together': 293,
#  'said': 294,
#  'takes': 295,
#  'seem': 296,
#  'american': 297,
#  'everyone': 298,
#  'instead': 299,
#  'special': 300,
#  'beautiful': 301,
#  'seeing': 302,
#  'later': 303,
#  'left': 304,
#  'audience': 305,
#  'himself': 306,
#  'war': 307,
#  'version': 308,
#  'excellent': 309,
#  'john': 310,
#  'idea': 311,
#  'night': 312,
#  'shot': 313,
#  'black': 314,
#  'high': 315,
#  'simply': 316,
#  'youre': 317,
#  'fan': 318,
#  'completely': 319,
#  'used': 320,
#  'house': 321,
#  'nice': 322,
#  'read': 323,
#  'else': 324,
#  'wife': 325,
#  'poor': 326,
#  'death': 327,
#  'kids': 328,
#  'short': 329,
#  'friends': 330,
#  'help': 331,
#  'along': 332,
#  'year': 333,
#  'second': 334,
#  'men': 335,
#  'star': 336,
#  'mind': 337,
#  'use': 338,
#  'need': 339,
#  'less': 340,
#  'home': 341,
#  'given': 342,
#  'try': 343,
#  'enjoy': 344,
#  'half': 345,
#  'boring': 346,
#  'until': 347,
#  'classic': 348,
#  'truly': 349,
#  'either': 350,
#  'rest': 351,
#  'recommend': 352,
#  'performances': 353,
#  'couple': 354,
#  'production': 355,
#  'wrong': 356,
#  'dead': 357,
#  'line': 358,
#  'father': 359,
#  'hollywood': 360,
#  'start': 361,
#  'next': 362,
#  'tell': 363,
#  'stupid': 364,
#  'came': 365,
#  'women': 366,
#  'getting': 367,
#  'understand': 368,
#  'remember': 369,
#  'full': 370,
#  'let': 371,
#  'school': 372,
#  'keep': 373,
#  'camera': 374,
#  'others': 375,
#  'terrible': 376,
#  'moments': 377,
#  'awful': 378,
#  'mean': 379,
#  'wonderful': 380,
#  'sex': 381,
#  'perhaps': 382,
#  'playing': 383,
#  'itself': 384,
#  'video': 385,
#  'name': 386,
#  'gives': 387,
#  'human': 388,
#  'often': 389,
#  'doing': 390,
#  'budget': 391,
#  'small': 392,
#  'definitely': 393,
#  'couldnt': 394,
#  'perfect': 395,
#  'episode': 396,
#  'person': 397,
#  'early': 398,
#  'top': 399,
#  'went': 400,
#  'dialogue': 401,
#  'absolutely': 402,
#  'guys': 403,
#  'lines': 404,
#  'piece': 405,
#  'face': 406,
#  'certainly': 407,
#  'become': 408,
#  'liked': 409,
#  'stars': 410,
#  'case': 411,
#  'sort': 412,
#  'head': 413,
#  'loved': 414,
#  'hope': 415,
#  'entire': 416,
#  'supposed': 417,
#  'felt': 418,
#  'lost': 419,
#  'several': 420,
#  'style': 421,
#  'mother': 422,
#  'live': 423,
#  'entertaining': 424,
#  'written': 425,
#  'picture': 426,
#  'against': 427,
#  'finally': 428,
#  'worse': 429,
#  'laugh': 430,
#  'title': 431,
#  'waste': 432,
#  'problem': 433,
#  'sound': 434,
#  'friend': 435,
#  'boy': 436,
#  'beginning': 437,
#  'shes': 438,
#  'seemed': 439,
#  'totally': 440,
#  'wanted': 441,
#  'based': 442,
#  'cinema': 443,
#  'yes': 444,
#  'dark': 445,
#  'mr': 446,
#  'care': 447,
#  'becomes': 448,
#  'fans': 449,
#  'humor': 450,
#  'already': 451,
#  'lead': 452,
#  'wont': 453,
#  'example': 454,
#  'guess': 455,
#  'final': 456,
#  'youll': 457,
#  'evil': 458,
#  'called': 459,
#  'direction': 460,
#  'children': 461,
#  'lives': 462,
#  'able': 463,
#  'id': 464,
#  'game': 465,
#  'turn': 466,
#  'low': 467,
#  'throughout': 468,
#  'drama': 469,
#  'wants': 470,
#  'white': 471,
#  'oh': 472,
#  'girls': 473,
#  'days': 474,
#  'despite': 475,
#  'fine': 476,
#  '\x96': 477,
#  'under': 478,
#  'quality': 479,
#  'amazing': 480,
#  'horrible': 481,
#  'theyre': 482,
#  'history': 483,
#  'writing': 484,
#  'works': 485,
#  'kill': 486,
#  'tries': 487,
#  'turns': 488,
#  'enjoyed': 489,
#  'gave': 490,
#  'act': 491,
#  'unfortunately': 492,
#  'killer': 493,
#  'son': 494,
#  'michael': 495,
#  'side': 496,
#  'past': 497,
#  'parts': 498,
#  'favorite': 499,
#  'flick': 500,
#  'behind': 501,
#  'matter': 502,
#  'expect': 503,
#  'car': 504,
#  'run': 505,
#  'town': 506,
#  'brilliant': 507,
#  'stuff': 508,
#  'eyes': 509,
#  'ones': 510,
#  'starts': 511,
#  'obviously': 512,
#  'myself': 513,
#  'sometimes': 514,
#  'themselves': 515,
#  'says': 516,
#  'viewer': 517,
#  'killed': 518,
#  'overall': 519,
#  'thinking': 520,
#  'took': 521,
#  'soon': 522,
#  'directed': 523,
#  'group': 524,
#  'heart': 525,
#  'actress': 526,
#  'late': 527,
#  'decent': 528,
#  'city': 529,
#  'art': 530,
#  'heard': 531,
#  'genre': 532,
#  'happens': 533,
#  'feeling': 534,
#  'kid': 535,
#  'highly': 536,
#  'hell': 537,
#  'fight': 538,
#  'except': 539,
#  'child': 540,
#  'extremely': 541,
#  'hour': 542,
#  'ill': 543,
#  'leave': 544,
#  'wouldnt': 545,
#  'close': 546,
#  'told': 547,
#  'blood': 548,
#  'lack': 549,
#  'experience': 550,
#  'police': 551,
#  'etc': 552,
#  'moment': 553,
#  'coming': 554,
#  'wonder': 555,
#  'stories': 556,
#  'looked': 557,
#  'strong': 558,
#  'involved': 559,
#  'chance': 560,
#  'daughter': 561,
#  'score': 562,
#  'type': 563,
#  'particularly': 564,
#  'including': 565,
#  'hand': 566,
#  'living': 567,
#  'attempt': 568,
#  'save': 569,
#  'complete': 570,
#  'simple': 571,
#  'serious': 572,
#  'shown': 573,
#  'taken': 574,
#  'roles': 575,
#  'god': 576,
#  'obvious': 577,
#  'hilarious': 578,
#  'happened': 579,
#  'happen': 580,
#  'violence': 581,
#  'stop': 582,
#  'cool': 583,
#  'james': 584,
#  'across': 585,
#  'known': 586,
#  'murder': 587,
#  'voice': 588,
#  'exactly': 589,
#  'song': 590,
#  'opening': 591,
#  'ago': 592,
#  'number': 593,
#  'robert': 594,
#  'usually': 595,
#  'released': 596,
#  'slow': 597,
#  'saying': 598,
#  'huge': 599,
#  'ok': 600,
#  'wish': 601,
#  'hours': 602,
#  'order': 603,
#  'david': 604,
#  'cinematography': 605,
#  'interest': 606,
#  'jokes': 607,
#  'whose': 608,
#  'reality': 609,
#  'english': 610,
#  'alone': 611,
#  'crap': 612,
#  'relationship': 613,
#  'sad': 614,
#  'hit': 615,
#  'lets': 616,
#  'running': 617,
#  'none': 618,
#  'shots': 619,
#  'possible': 620,
#  'talent': 621,
#  'seriously': 622,
#  'age': 623,
#  'yourself': 624,
#  'annoying': 625,
#  'cut': 626,
#  'today': 627,
#  'gore': 628,
#  'career': 629,
#  'started': 630,
#  'call': 631,
#  'major': 632,
#  'brother': 633,
#  'female': 634,
#  'usual': 635,
#  'please': 636,
#  'taking': 637,
#  'hero': 638,
#  'ends': 639,
#  'somewhat': 640,
#  'knew': 641,
#  'view': 642,
#  'ridiculous': 643,
#  'mostly': 644,
#  'important': 645,
#  'documentary': 646,
#  'knows': 647,
#  'beyond': 648,
#  'change': 649,
#  'body': 650,
#  'finds': 651,
#  'turned': 652,
#  'opinion': 653,
#  'power': 654,
#  'words': 655,
#  'silly': 656,
#  'strange': 657,
#  'word': 658,
#  'due': 659,
#  'novel': 660,
#  'upon': 661,
#  'anyway': 662,
#  'scary': 663,
#  'talking': 664,
#  'apparently': 665,
#  'attention': 666,
#  'directors': 667,
#  'local': 668,
#  'husband': 669,
#  'happy': 670,
#  'clearly': 671,
#  'musical': 672,
#  'episodes': 673,
#  'cheap': 674,
#  'four': 675,
#  'level': 676,
#  'single': 677,
#  'problems': 678,
#  'room': 679,
#  'arent': 680,
#  'basically': 681,
#  'country': 682,
#  'disappointed': 683,
#  'tells': 684,
#  'sequence': 685,
#  'events': 686,
#  'british': 687,
#  'television': 688,
#  'modern': 689,
#  'miss': 690,
#  'talk': 691,
#  'light': 692,
#  'songs': 693,
#  'whats': 694,
#  'appears': 695,
#  'rating': 696,
#  'whether': 697,
#  'french': 698,
#  'sets': 699,
#  'giving': 700,
#  'easily': 701,
#  'bring': 702,
#  'predictable': 703,
#  'supporting': 704,
#  'add': 705,
#  'havent': 706,
#  'review': 707,
#  'dialog': 708,
#  'mention': 709,
#  'falls': 710,
#  'lots': 711,
#  'similar': 712,
#  'soundtrack': 713,
#  'jack': 714,
#  'romantic': 715,
#  'team': 716,
#  'needs': 717,
#  'bunch': 718,
#  'ten': 719,
#  'george': 720,
#  'viewers': 721,
#  'above': 722,
#  'future': 723,
#  'enjoyable': 724,
#  'message': 725,
#  'hate': 726,
#  'certain': 727,
#  'tried': 728,
#  'moving': 729,
#  'five': 730,
#  'showing': 731,
#  'surprised': 732,
#  'entertainment': 733,
#  'within': 734,
#  'comic': 735,
#  'earth': 736,
#  'clear': 737,
#  'parents': 738,
#  'storyline': 739,
#  'space': 740,
#  'middle': 741,
#  'among': 742,
#  'filmed': 743,
#  'named': 744,
#  'fall': 745,
#  'dull': 746,
#  'theme': 747,
#  'easy': 748,
#  'theater': 749,
#  'ways': 750,
#  'king': 751,
#  'feels': 752,
#  'typical': 753,
#  'greatest': 754,
#  'release': 755,
#  'kept': 756,
#  'thriller': 757,
#  'using': 758,
#  'near': 759,
#  'comments': 760,
#  'stay': 761,
#  'sequel': 762,
#  'buy': 763,
#  'doubt': 764,
#  'gone': 765,
#  'working': 766,
#  'deal': 767,
#  'effort': 768,
#  'actual': 769,
#  'nearly': 770,
#  'monster': 771,
#  'writer': 772,
#  'elements': 773,
#  'sorry': 774,
#  'means': 775,
#  'tale': 776,
#  'fantastic': 777,
#  'famous': 778,
#  'brought': 779,
#  'suspense': 780,
#  'die': 781,
#  'subject': 782,
#  'editing': 783,
#  'minute': 784,
#  'straight': 785,
#  'boys': 786,
#  'rock': 787,
#  'herself': 788,
#  'points': 789,
#  'realistic': 790,
#  'imagine': 791,
#  'th': 792,
#  'general': 793,
#  'feature': 794,
#  'viewing': 795,
#  'lady': 796,
#  'sister': 797,
#  'leads': 798,
#  'move': 799,
#  'class': 800,
#  'youve': 801,
#  'peter': 802,
#  'dr': 803,
#  'mystery': 804,
#  'richard': 805,
#  'form': 806,
#  'begins': 807,
#  'reviews': 808,
#  'hear': 809,
#  'check': 810,
#  'material': 811,
#  'somehow': 812,
#  'dog': 813,
#  'learn': 814,
#  'forget': 815,
#  'whos': 816,
#  'sit': 817,
#  'animation': 818,
#  'particular': 819,
#  'figure': 820,
#  'killing': 821,
#  'weak': 822,
#  'period': 823,
#  'premise': 824,
#  'rent': 825,
#  'expected': 826,
#  'believable': 827,
#  'surprise': 828,
#  'sequences': 829,
#  'decided': 830,
#  'atmosphere': 831,
#  'paul': 832,
#  'eventually': 833,
#  'crime': 834,
#  'deep': 835,
#  'wait': 836,
#  'avoid': 837,
#  'fast': 838,
#  'difficult': 839,
#  'leaves': 840,
#  'red': 841,
#  'eye': 842,
#  'tom': 843,
#  'okay': 844,
#  'became': 845,
#  'possibly': 846,
#  'york': 847,
#  'truth': 848,
#  'indeed': 849,
#  'emotional': 850,
#  'situation': 851,
#  'follow': 852,
#  'average': 853,
#  'lame': 854,
#  'poorly': 855,
#  'dance': 856,
#  'forced': 857,
#  'meet': 858,
#  'needed': 859,
#  'stand': 860,
#  'footage': 861,
#  'shame': 862,
#  'begin': 863,
#  'whatever': 864,
#  'scifi': 865,
#  'oscar': 866,
#  'crew': 867,
#  'open': 868,
#  'memorable': 869,
#  'features': 870,
#  'meets': 871,
#  'reading': 872,
#  'doctor': 873,
#  'season': 874,
#  'previous': 875,
#  'whom': 876,
#  'question': 877,
#  'filmmakers': 878,
#  'sexual': 879,
#  'write': 880,
#  'romance': 881,
#  'credits': 882,
#  'writers': 883,
#  'beauty': 884,
#  'interested': 885,
#  'personal': 886,
#  'cheesy': 887,
#  'nor': 888,
#  'gay': 889,
#  'imdb': 890,
#  'third': 891,
#  'keeps': 892,
#  'hot': 893,
#  'western': 894,
#  'superb': 895,
#  'unless': 896,
#  'nature': 897,
#  'society': 898,
#  'inside': 899,
#  'total': 900,
#  'otherwise': 901,
#  'hands': 902,
#  'perfectly': 903,
#  'towards': 904,
#  'note': 905,
#  'male': 906,
#  'incredibly': 907,
#  'sounds': 908,
#  'weird': 909,
#  'box': 910,
#  'screenplay': 911,
#  'result': 912,
#  'de': 913,
#  'effect': 914,
#  'japanese': 915,
#  'comment': 916,
#  'battle': 917,
#  'quickly': 918,
#  'plus': 919,
#  'masterpiece': 920,
#  'worked': 921,
#  'street': 922,
#  'realize': 923,
#  'b': 924,
#  'laughs': 925,
#  'unique': 926,
#  'badly': 927,
#  'crazy': 928,
#  'copy': 929,
#  'earlier': 930,
#  'older': 931,
#  'various': 932,
#  'brings': 933,
#  'america': 934,
#  'background': 935,
#  'appear': 936,
#  'stage': 937,
#  'air': 938,
#  'plenty': 939,
#  'setting': 940,
#  'fairly': 941,
#  'free': 942,
#  'island': 943,
#  'admit': 944,
#  'lee': 945,
#  'powerful': 946,
#  'ask': 947,
#  'front': 948,
#  'creepy': 949,
#  'portrayed': 950,
#  'dramatic': 951,
#  'business': 952,
#  'directing': 953,
#  'leading': 954,
#  'spent': 955,
#  'following': 956,
#  'forward': 957,
#  'acted': 958,
#  'remake': 959,
#  'joe': 960,
#  'rich': 961,
#  'development': 962,
#  'mark': 963,
#  'pay': 964,
#  'mess': 965,
#  'baby': 966,
#  'manages': 967,
#  'deserves': 968,
#  'dumb': 969,
#  'outside': 970,
#  'meant': 971,
#  'attempts': 972,
#  'political': 973,
#  'fire': 974,
#  'fails': 975,
#  'expecting': 976,
#  'caught': 977,
#  'create': 978,
#  'water': 979,
#  'agree': 980,
#  'ideas': 981,
#  'reasons': 982,
#  'hardly': 983,
#  'bill': 984,
#  'wasted': 985,
#  'cover': 986,
#  'fighting': 987,
#  'missing': 988,
#  'return': 989,
#  'party': 990,
#  'joke': 991,
#  'recently': 992,
#  'success': 993,
#  'present': 994,
#  'apart': 995,
#  'secret': 996,
#  'cop': 997,
#  'twist': 998,
#  'la': 999,
#  'large': 1000,
#  ...}

# %%
encoded = [[vocab[word] for word in element if word in vocab] for element in review]

# %%
len(encoded)
# Out:
# 49582

# %%
len(encoded[0])
# Out:
# 300

# %%
len(encoded[1])
# Out:
# 156

# %%
MAX_LEN = 100

# %%
padded_review = pad_sequences(encoded, maxlen = MAX_LEN, padding = 'post', truncating = 'post')
padded_review
# Out:
# array([[  27,    4,    1, ..., 6648, 2504, 1052],
#        [   3,  380,  115, ...,    1, 1855,   62],
#        [   9,  192,   10, ...,  149, 2940,    9],
#        ...,
#        [   9,  224,    3, ...,  124,  110,    4],
#        [ 143,  161,    5, ..., 8368, 5410,    2],
#        [  54,   27, 5639, ...,  286,  318,   34]], dtype=int32)

# %%
padded_review.shape
# Out:
# (49582, 100)

# %%
label_encoder = LabelEncoder()

# %%
encoded_target = label_encoder.fit_transform(target)
encoded_target
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(padded_review, encoded_target, test_size = 0.2, random_state = 42)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.long)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.long)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# %%
train_data = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
test_data = torch.utils.data.TensorDataset(X_test_tensor, y_test_tensor)

# %%
BATCH_SIZE = 32
train_loader = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=BATCH_SIZE)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, num_layers=n_layers,
                          bidirectional=bidirectional, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        embedded = self.dropout(self.embedding(text))
        output, hidden = self.rnn(embedded)

        if self.rnn.bidirectional:
            hidden = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        else:
            hidden = hidden[-1,:,:]
        output = self.fc(hidden)
        return output

# %%
VOCAB_SIZE = len(vocab) + 1
EMBEDDING_DIM = 100
HIDDEN_DIM = 128
OUTPUT_DIM = 1
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.5

model = RNN(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT)

model
# Out:
# RNN(
#   (embedding): Embedding(215440, 100)
#   (rnn): RNN(100, 128, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
optimizer = optim.Adam(model.parameters())

# %%
criterion = nn.BCEWithLogitsLoss()

# %%
def binary_accuracy(preds, y):
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float()
    acc = correct.sum() / len(correct)
    return acc

# %%
def train(model, iterator, optimizer, criterion):
    model.train()
    epoch_loss = 0
    epoch_acc = 0

    for batch in iterator:
        optimizer.zero_grad()
        text, labels = batch
        text = text.to(device)
        labels = labels.to(device)

        predictions = model(text).squeeze(1)
        loss = criterion(predictions, labels)
        acc = binary_accuracy(predictions, labels)

        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    model.eval()
    epoch_loss = 0
    epoch_acc = 0

    with torch.no_grad():
        for batch in iterator:
            text, labels = batch
            text = text.to(device)
            labels = labels.to(device)

            predictions = model(text).squeeze(1)
            loss = criterion(predictions, labels)
            acc = binary_accuracy(predictions, labels)

            epoch_loss += loss.item()
            epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def predict_sentiment(model, sentence, vocab, max_len):
    model.eval()

    tokenized = word_tokenize(sentence.lower())
    indexed = [vocab[word] for word in tokenized if word in vocab]
    padded = pad_sequences([indexed], maxlen=max_len, padding='post', truncating='post')

    tensor = torch.LongTensor(padded).to(device)

    prediction = torch.sigmoid(model(tensor))
    return prediction.item()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
criterion = criterion.to(device)

# %%
N_EPOCHS = 20
train_losses = []
train_accuracies = []
valid_losses = []
valid_accuracies = []

for epoch in range(N_EPOCHS):
    train_loss, train_acc = train(model, train_loader, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, test_loader, criterion)

    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    valid_losses.append(valid_loss)
    valid_accuracies.append(valid_acc)

    print(f'Epoch: {epoch+1}')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\tVal. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:.2f}%')

print("Training complete.")
# Out:
# Epoch: 1
# 	Train Loss: 0.693 | Train Acc: 53.52%
# 	Val. Loss: 0.692 | Val. Acc: 57.03%
# Epoch: 2
# 	Train Loss: 0.686 | Train Acc: 54.98%
# 	Val. Loss: 0.687 | Val. Acc: 55.10%
# Epoch: 3
# 	Train Loss: 0.678 | Train Acc: 57.59%
# 	Val. Loss: 0.673 | Val. Acc: 58.47%
# Epoch: 4
# 	Train Loss: 0.674 | Train Acc: 58.09%
# 	Val. Loss: 0.672 | Val. Acc: 59.18%
# Epoch: 5
# 	Train Loss: 0.662 | Train Acc: 60.31%
# 	Val. Loss: 0.631 | Val. Acc: 65.10%
# Epoch: 6
# 	Train Loss: 0.661 | Train Acc: 59.81%
# 	Val. Loss: 0.677 | Val. Acc: 57.20%
# Epoch: 7
# 	Train Loss: 0.646 | Train Acc: 62.62%
# 	Val. Loss: 0.588 | Val. Acc: 69.80%
# Epoch: 8
# 	Train Loss: 0.624 | Train Acc: 65.70%
# 	Val. Loss: 0.575 | Val. Acc: 70.29%
# Epoch: 9
# 	Train Loss: 0.617 | Train Acc: 66.14%
# 	Val. Loss: 0.636 | Val. Acc: 64.30%
# Epoch: 10
# 	Train Loss: 0.589 | Train Acc: 68.84%
# 	Val. Loss: 0.609 | Val. Acc: 65.95%
# Epoch: 11
# 	Train Loss: 0.549 | Train Acc: 72.37%
# 	Val. Loss: 0.510 | Val. Acc: 75.53%
# Epoch: 12
# 	Train Loss: 0.616 | Train Acc: 65.92%
# 	Val. Loss: 0.633 | Val. Acc: 64.88%
# Epoch: 13
# 	Train Loss: 0.553 | Train Acc: 72.01%
# 	Val. Loss: 0.636 | Val. Acc: 63.22%
# Epoch: 14
# 	Train Loss: 0.579 | Train Acc: 69.21%
# 	Val. Loss: 0.542 | Val. Acc: 72.95%
# Epoch: 15
# 	Train Loss: 0.534 | Train Acc: 73.60%
# 	Val. Loss: 0.539 | Val. Acc: 73.70%
# Epoch: 16
# 	Train Loss: 0.505 | Train Acc: 75.94%
# 	Val. Loss: 0.542 | Val. Acc: 73.66%
# Epoch: 17
# 	Train Loss: 0.493 | Train Acc: 76.63%
# 	Val. Loss: 0.480 | Val. Acc: 77.31%
# Epoch: 18
# 	Train Loss: 0.480 | Train Acc: 77.35%
# 	Val. Loss: 0.496 | Val. Acc: 77.02%
# Epoch: 19
# 	Train Loss: 0.486 | Train Acc: 77.34%
# 	Val. Loss: 0.550 | Val. Acc: 73.40%
# Epoch: 20
# 	Train Loss: 0.505 | Train Acc: 75.92%
# 	Val. Loss: 0.599 | Val. Acc: 72.58%
# Training complete.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Loss over epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Accuracy over epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()

plt.show()

# %%
text1 = "The Story of Us is a beautifully crafted film with heartfelt performances, stunning visuals, and an emotional score. A must-watch that leaves you inspired and uplifted!"
text2 = "The Story of Us is predictable and dull, with shallow characters and a sluggish pace. It fails to engage or evoke any genuine emotions."

# %%
predicted_sentiment = predict_sentiment(model, text1, vocab, MAX_LEN)
print(predicted_sentiment)
ans = 1 if predicted_sentiment >= 0.6 else 0
ans = np.array([ans])
print(f"Predicted sentiment for the sentence: {label_encoder.inverse_transform(ans)}")
# Out:
# 0.879703938961029
# Predicted sentiment for the sentence: ['positive']

# %%
predicted_sentiment = predict_sentiment(model, text2, vocab, MAX_LEN)
print(predicted_sentiment)
ans = 1 if predicted_sentiment >= 0.6 else 0
ans = np.array([ans])
print(f"Predicted sentiment for the sentence: {label_encoder.inverse_transform(ans)}")
# Out:
# 0.5795952081680298
# Predicted sentiment for the sentence: ['negative']
